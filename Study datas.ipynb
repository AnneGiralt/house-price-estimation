# %%
import pandas as pd

df = pd.read_csv('Datas/housing.csv')

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
# longitude             20640 non-null float64
# latitude              20640 non-null float64
# housing_median_age    20640 non-null float64
# total_rooms           20640 non-null float64
# total_bedrooms        20433 non-null float64
# population            20640 non-null float64
# households            20640 non-null float64
# median_income         20640 non-null float64
# median_house_value    20640 non-null float64
# ocean_proximity       20640 non-null object
# dtypes: float64(9), object(1)
# memory usage: 1.5+ MB

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
df.hist(bins=50, figsize=(20,15))
plt.show()

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
X = df[['longitude','latitude','housing_median_age','total_rooms', 'total_bedrooms', 'population', 'households', 'median_income', 'ocean_proximity']]

# %%
X.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income ocean_proximity
# 0       322.0       126.0         8.3252        NEAR BAY
# 1      2401.0      1138.0         8.3014        NEAR BAY
# 2       496.0       177.0         7.2574        NEAR BAY
# 3       558.0       219.0         5.6431        NEAR BAY
# 4       565.0       259.0         3.8462        NEAR BAY

# %%
import numpy as np
from sklearn.model_selection import train_test_split

# %%
Y = df[['median_house_value']]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
df["income_cat"] = np.ceil(df["median_income"] / 1.5)
df["income_cat"].describe()
# Out:
# count    20640.000000
# mean         3.093362
# std          1.303707
# min          1.000000
# 25%          2.000000
# 50%          3.000000
# 75%          4.000000
# max         11.000000
# Name: income_cat, dtype: float64

# %%
df["income_cat"].where(df["income_cat"] < 5, 5.0, inplace=True)
df["income_cat"].describe()
# Out:
# count    20640.000000
# mean         3.006686
# std          1.054618
# min          1.000000
# 25%          2.000000
# 50%          3.000000
# 75%          4.000000
# max          5.000000
# Name: income_cat, dtype: float64

# %%
from sklearn.model_selection import StratifiedShuffleSplit

split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)

for train_index, test_index in split.split(df, df["income_cat"]):
    strat_train_set = df.loc[train_index]
    strat_test_set = df.loc[test_index]

# %%
strat_test_set["income_cat"].value_counts() / len(strat_test_set)
# Out:
# 3.0    0.350533
# 2.0    0.318798
# 4.0    0.176357
# 5.0    0.114583
# 1.0    0.039729
# Name: income_cat, dtype: float64

# %%
df["income_cat"].value_counts() / len(df)
# Out:
# 3.0    0.350581
# 2.0    0.318847
# 4.0    0.176308
# 5.0    0.114438
# 1.0    0.039826
# Name: income_cat, dtype: float64

# %%
for set in (strat_train_set, strat_test_set):
    set.drop(["income_cat"], axis=1, inplace=True)

# %%
df_train = strat_train_set.copy()

# %%
df_train.plot(kind="scatter", x="longitude", y="latitude", alpha =0.1)

# %%
df_train.plot(kind="scatter", x="longitude", y="latitude", alpha=0.4,
s=df_train["population"]/100, label="Population",
c="median_house_value", cmap=plt.get_cmap("jet"), colorbar=True,
)
plt.legend()

# %%
cor_matrix = df_train.corr()

# %%
cor_matrix
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924478           -0.105848     0.048871
# latitude            -0.924478  1.000000            0.005766    -0.039184
# housing_median_age  -0.105848  0.005766            1.000000    -0.364509
# total_rooms          0.048871 -0.039184           -0.364509     1.000000
# total_bedrooms       0.076598 -0.072419           -0.325047     0.929379
# population           0.108030 -0.115222           -0.298710     0.855109
# households           0.063070 -0.077647           -0.306428     0.918392
# median_income       -0.019583 -0.075205           -0.111360     0.200087
# median_house_value  -0.047432 -0.142724            0.114110     0.135097
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.076598    0.108030    0.063070      -0.019583
# latitude                 -0.072419   -0.115222   -0.077647      -0.075205
# ...

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df_train[["median_house_value", "median_income", "total_rooms", "housing_median_age"]], figsize=(12, 8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0E993310>,
# ...
#       dtype=object)

# %%
df_train["rooms_per_households"]= df_train["total_rooms"]/df_train["households"]
df_train["bedrooms_per_rooms"]= df_train["total_bedrooms"]/df_train["total_rooms"]
df_train["population_per_households"]= df_train["population"]/df_train["households"]

# %%
df_train.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  16512.000000  16512.000000        16512.000000  16512.000000
# mean    -119.575834     35.639577           28.653101   2622.728319
# std        2.001860      2.138058           12.574726   2138.458419
# min     -124.350000     32.540000            1.000000      6.000000
# 25%     -121.800000     33.940000           18.000000   1443.000000
# 50%     -118.510000     34.260000           29.000000   2119.500000
# 75%     -118.010000     37.720000           37.000000   3141.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    16354.000000  16512.000000  16512.000000   16512.000000
# mean       534.973890   1419.790819    497.060380       3.875589
# std        412.699041   1115.686241    375.720845       1.904950
# min          2.000000      3.000000      2.000000       0.499900
# ...

# %%
cor_matrix = df_train.corr()

# %%
cor_matrix
# Out:
#                            longitude  latitude  housing_median_age  \
# longitude                   1.000000 -0.924478           -0.105848
# latitude                   -0.924478  1.000000            0.005766
# housing_median_age         -0.105848  0.005766            1.000000
# total_rooms                 0.048871 -0.039184           -0.364509
# total_bedrooms              0.076598 -0.072419           -0.325047
# population                  0.108030 -0.115222           -0.298710
# households                  0.063070 -0.077647           -0.306428
# median_income              -0.019583 -0.075205           -0.111360
# median_house_value         -0.047432 -0.142724            0.114110
# rooms_per_house            -0.028345  0.107621           -0.147186
# rooms_per_households       -0.028345  0.107621           -0.147186
# bedrooms_per_households     0.012768  0.070591           -0.075323
# population_per_households  -0.000410  0.005420            0.015031
# ...

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df_train[["median_house_value", "median_income", "rooms_per_households", "population_per_households"]], figsize=(12, 8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11B096F0>,
# ...
#       dtype=object)

# %%
df_train.plot(kind="scatter", x= "rooms_per_households", y = "median_house_value", alpha=0.1 )

# %%
df_big_house = df_train.loc[df_train['rooms_per_households'] > 100]

# %%
df_big_house
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1979    -120.08     38.80                34.0       1988.0           511.0
# 1914    -120.10     38.91                33.0       1561.0           282.0
#
#       population  households  median_income  median_house_value  \
# 1979        36.0        15.0          4.625            162500.0
# 1914        30.0        11.0          1.875            500001.0
#
#      ocean_proximity  rooms_per_house  rooms_per_households  \
# 1979          INLAND       132.533333            132.533333
# 1914          INLAND       141.909091            141.909091
#
#       bedrooms_per_households  population_per_households  bedrooms_per_rooms
# 1979                34.066667                   2.400000            0.257042
# 1914                25.636364                   2.727273            0.180653
